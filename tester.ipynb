# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib import cm

data_to_load_2016 = "Resources/OSMI_2016.csv"
data_to_load_2017 =  "Resources/OSMI_2017.csv"
data_to_load_2018 =  "Resources/OSMI_2018.csv"


# Read the City and Ride Data
survey_2016 = pd.read_csv(data_to_load_2016)
survey_2017 = pd.read_csv(data_to_load_2017)
survey_2018 = pd.read_csv(data_to_load_2018)
# Combine the data into a single dataset
# pyber = ride.merge(city, how="left", on="city")
# pyber.to_csv("data/pyber.csv", index=False, header=True)

# Display the data table for preview

# %%
survey_2016.head()
# Out:
#    Are you self-employed?  \
# 0                       0
# 1                       0
# 2                       0
# 3                       1
# 4                       0
#
#   How many employees does your company or organization have?  \
# 0                                             26-100
# 1                                               6-25
# 2                                               6-25
# 3                                                NaN
# 4                                               6-25
#
#    Is your employer primarily a tech company/organization?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                NaN
# 4                                                0.0
#
#    Is your primary role within your company related to tech/IT?  \
# 0                                                NaN
# ...
